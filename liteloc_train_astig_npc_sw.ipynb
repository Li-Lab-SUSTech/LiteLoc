# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "5"

from utils.help_utils import load_yaml, writelog, setup_seed
from utils.visual_utils import show_sample_psf, show_train_img
from network.loc_model import LitelocModel

# %%
setup_seed(15)

yaml_file = 'param_astig_train_oil_spline.yaml'
params = load_yaml(yaml_file)

writelog(params.Training.result_path)

print(params)

# %%
liteloc = LitelocModel(params)

# %%
fig = show_sample_psf(psf_pars=params.PSF_model, train_pars=params.Training)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'Qt5Agg')
#
# File ~/anaconda3/envs/liteloc/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/anaconda3/envs/liteloc/lib/python3.8/site-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
# ...
